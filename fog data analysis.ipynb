# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sb

# %%
fog_data = pd.read_csv ('C:\\Users\\DELL\\Desktop\\NIT research\\pythonsim\\python sim\\fog\\Results.csv')
fog_data.head()
# Out:
#    id    type                   app module message  DES.src  DES.dst  \
# 0   3  COMP_M  who_may_not_be_named   Mod1  M.sens        4        8
# 1   2  COMP_M  who_may_not_be_named   Mod1  M.sens        2        7
# 2   1  COMP_M  who_may_not_be_named   Mod1  M.sens        0        6
# 3   1  COMP_M  who_may_not_be_named   Mod2  M.data        6       17
# 4   1  COMP_M  who_may_not_be_named   Mod3   M.pre       17       28
#
#    TOPO.src  TOPO.dst module.src     service    time_in    time_out  \
# 0        16         1     Sensor  187.813884  10.000002  197.813886
# 1        14         0     Sensor  204.743581  10.000003  214.743584
# 2        12        10     Sensor    0.125000  10.000005   10.125005
# 3        10        10       Mod1    0.125000  10.125005   10.250005
# 4        10        10       Mod2    0.250000  10.250005   10.500005
#
#    time_emit  time_reception
# 0  10.000000       10.000002
# 1  10.000000       10.000003
# 2  10.000000       10.000005
# ...

# %%
fog_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              76 non-null     int64
#  1   type            76 non-null     object
#  2   app             76 non-null     object
#  3   module          76 non-null     object
#  4   message         76 non-null     object
#  5   DES.src         76 non-null     int64
#  6   DES.dst         76 non-null     int64
#  7   TOPO.src        76 non-null     int64
#  8   TOPO.dst        76 non-null     int64
#  9   module.src      76 non-null     object
#  10  service         76 non-null     float64
#  11  time_in         76 non-null     float64
#  12  time_out        76 non-null     float64
#  13  time_emit       76 non-null     float64
#  14  time_reception  76 non-null     float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 9.0+ KB

# %%
fog_data.describe()
# Out:
#                id    DES.src    DES.dst   TOPO.src   TOPO.dst     service  \
# count   76.000000  76.000000  76.000000  76.000000  76.000000   76.000000
# mean    32.671053   7.526316  17.131579  10.315789   5.789474  196.613920
# std     36.362760   7.498397   9.289912   4.716526   3.552711  148.785181
# min      1.000000   0.000000   6.000000   0.000000   0.000000    0.125000
# 25%      7.750000   2.000000   8.000000   7.750000   3.000000  135.858263
# 50%     17.000000   5.000000  16.000000  11.000000   6.000000  204.743581
# 75%     44.000000  11.250000  24.000000  14.000000   9.250000  244.210518
# max    142.000000  28.000000  38.000000  16.000000  10.000000  728.856953
#
#           time_in    time_out   time_emit  time_reception
# count   76.000000   76.000000   76.000000       76.000000
# mean   254.029102  450.643022  196.134991      196.134993
# std    153.804814  224.625653  147.964051      147.964051
# min     10.000002   10.125005   10.000000       10.000002
# ...

# %%
df = pd.DataFrame(fog_data)

# %%
df
# Out:
#      id    type                   app module message  DES.src  DES.dst  \
# 0     3  COMP_M  who_may_not_be_named   Mod1  M.sens        4        8
# 1     2  COMP_M  who_may_not_be_named   Mod1  M.sens        2        7
# 2     1  COMP_M  who_may_not_be_named   Mod1  M.sens        0        6
# 3     1  COMP_M  who_may_not_be_named   Mod2  M.data        6       17
# 4     1  COMP_M  who_may_not_be_named   Mod3   M.pre       17       28
# ..  ...     ...                   ...    ...     ...      ...      ...
# 71   12  COMP_M  who_may_not_be_named   Mod2  M.data        7       19
# 72  121  COMP_M  who_may_not_be_named   Mod2  M.data        6       18
# 73   32  COMP_M  who_may_not_be_named   Mod1  M.sens        2       16
# 74  142  COMP_M  who_may_not_be_named   Mod1  M.sens        0        6
# 75   30  COMP_M  who_may_not_be_named   Mod1  M.sens        4       14
#
#     TOPO.src  TOPO.dst module.src     service     time_in    time_out  \
# ...

# %%
id_data = df ['id'].tolist()

# %%
id_data
# Out:
# [3,
#  2,
#  1,
#  1,
#  1,
#  1,
#  6,
#  5,
#  4,
#  7,
#  8,
#  9,
#  10,
#  11,
#  11,
#  22,
#  22,
#  33,
#  33,
#  44,
#  44,
#  55,
#  55,
#  13,
#  3,
#  16,
#  5,
#  17,
#  6,
#  12,
#  2,
#  66,
#  66,
#  11,
#  21,
#  10,
#  10,
#  19,
#  8,
#  77,
#  20,
#  77,
#  22,
#  15,
#  18,
#  88,
#  99,
#  9,
#  33,
#  110,
#  7,
#  55,
#  27,
#  88,
#  3,
#  24,
#  28,
#  17,
#  17,
#  4,
#  44,
#  121,
#  23,
#  110,
#  6,
#  13,
#  66,
#  132,
#  99,
#  5,
#  16,
#  12,
#  121,
#  32,
#  142,
#  30]

# %%
fog_data.drop('type', axis = 'columns')
# Out:
#      id                   app module message  DES.src  DES.dst  TOPO.src  \
# 0     3  who_may_not_be_named   Mod1  M.sens        4        8        16
# 1     2  who_may_not_be_named   Mod1  M.sens        2        7        14
# 2     1  who_may_not_be_named   Mod1  M.sens        0        6        12
# 3     1  who_may_not_be_named   Mod2  M.data        6       17        10
# 4     1  who_may_not_be_named   Mod3   M.pre       17       28        10
# ..  ...                   ...    ...     ...      ...      ...       ...
# 71   12  who_may_not_be_named   Mod2  M.data        7       19         0
# 72  121  who_may_not_be_named   Mod2  M.data        6       18        10
# 73   32  who_may_not_be_named   Mod1  M.sens        2       16        14
# 74  142  who_may_not_be_named   Mod1  M.sens        0        6        12
# 75   30  who_may_not_be_named   Mod1  M.sens        4       14        16
#
#     TOPO.dst module.src     service     time_in    time_out   time_emit  \
# ...

# %%
fog_data.drop('app', axis = 'columns')
fog_data.drop('type', axis = 'columns')
# Out:
#      id                   app module message  DES.src  DES.dst  TOPO.src  \
# 0     3  who_may_not_be_named   Mod1  M.sens        4        8        16
# 1     2  who_may_not_be_named   Mod1  M.sens        2        7        14
# 2     1  who_may_not_be_named   Mod1  M.sens        0        6        12
# 3     1  who_may_not_be_named   Mod2  M.data        6       17        10
# 4     1  who_may_not_be_named   Mod3   M.pre       17       28        10
# ..  ...                   ...    ...     ...      ...      ...       ...
# 71   12  who_may_not_be_named   Mod2  M.data        7       19         0
# 72  121  who_may_not_be_named   Mod2  M.data        6       18        10
# 73   32  who_may_not_be_named   Mod1  M.sens        2       16        14
# 74  142  who_may_not_be_named   Mod1  M.sens        0        6        12
# 75   30  who_may_not_be_named   Mod1  M.sens        4       14        16
#
#     TOPO.dst module.src     service     time_in    time_out   time_emit  \
# ...

# %%
time_in = fog_data ['time_in'].tolist()

# %%
time_in
# Out:
# [10.000001973184956,
#  10.000003239986798,
#  10.000004906519052,
#  10.125004906519052,
#  10.250004906519052,
#  10.50000627149788,
#  20.00000182617047,
#  20.000003030147983,
#  20.00000303332256,
#  30.00000000002,
#  30.00000156877049,
#  30.0000019463026,
#  40.00000186100446,
#  40.00000510032421,
#  40.12500561164054,
#  80.00000490651904,
#  80.12500525519407,
#  110.0000054599353,
#  110.12500600592682,
#  150.00000510032422,
#  150.12500561035463,
#  190.00000490651908,
#  190.1250051467593,
#  197.8138859267424,
#  197.8138862283594,
#  201.06102059306667,
#  201.06102073282904,
#  206.45967339610496,
#  206.45967369545275,
#  214.7435844263448,
#  214.7435847177596,
#  220.00000545993527,
#  220.12500584097103,
#  244.86858679799855,
#  258.0643666111616,
#  258.06436699219734,
#  258.1893687355725,
#  258.48713797147815,
#  258.4871381318502,
#  260.00000510032424,
#  266.4776205220925,
#  267.93888920875145,
#  267.93889019533395,
#  267.985123926069,
# ...

# %%
time_out = fog_data ['time_out'].tolist()

# %%
time_out
# Out:
# [197.8138859267424,
#  214.7435844263448,
#  10.125004906519052,
#  10.250004906519052,
#  10.500004906519052,
#  739.3569593481732,
#  206.45967339610496,
#  201.06102059306667,
#  267.985123926069,
#  278.9375346023373,
#  258.48713797147815,
#  266.4776205220925,
#  258.0643666111616,
#  40.12500510032421,
#  244.86858679799855,
#  80.12500490651904,
#  267.93888920875145,
#  110.1250054599353,
#  353.0773236981519,
#  150.12500510032422,
#  398.110126503101,
#  190.12500490651908,
#  371.186022709678,
#  385.62776988029975,
#  384.2735577982939,
#  382.12203815598536,
#  449.9985553351464,
#  392.9193449660395,
#  434.9468100981604,
#  419.4871656127028,
#  451.2212032935495,
#  220.12500545993527,
#  438.1893705911282,
#  654.3557491707146,
#  476.1287313613187,
#  258.18936699219734,
#  633.8171366426873,
#  486.9742743741858,
#  463.2307193182082,
#  260.12500510032424,
#  502.9552390978824,
#  455.7527731623088,
#  753.8435255797841,
#  515.9702448188154,
# ...

# %%
mp.plot (time_in, time_out, color = 'red', marker = 'o')
mp.xlabel('TIME IN', fontsize = 14)
mp.ylabel('TIME OUT', fontsize = 14)
mp.grid (True)
mp.show()

# %%
mp.plot (time_in, time_out, linestyle='dashed', marker = 'o', markersize = 10, markerfacecolor = 'red')
mp.xlabel('time in')
mp.ylabel('time out')
mp.grid(True)
mp.show()

# %%
module = fog_data ['module'].tolist()
service = fog_data ['service'].tolist()
fig = mp.figure(figsize =(20, 7))
mp.pie(service, labels = module)
 
# show plot
mp.show()

# %%
time_emit = fog_data ['time_emit'].tolist()
time_reception = fog_data ['time_reception'].tolist()

mp.plot (time_reception, time_emit, linestyle = 'dashed', marker = 'o', markersize = 10, markerfacecolor = 'green')
mp.xlabel('TIME EMIT')
mp.ylabel('TIME RECEPTION')
mp.grid (True)
mp.show()

# %%
figure = mp.figure(figsize=(20, 7))
mp.pie(time_emit, labels = time_reception)
mp.show()

# %%
from statistics import *
list_data = []
label_list = []
time_in.sort()
list_data.append(mean (time_in))
label_list.append('TIME IN')
time_out.sort()
list_data.append(mean(time_out))
label_list.append('TIME OUT')
time_emit.sort()
list_data.append(mean(time_emit))
label_list.append('TIME EMIT')
time_reception.sort()
list_data.append(mean(time_reception))
label_list.append('TIME RECEPTION')

# %%
figuredata = mp.figure(figsize = (20, 7))
mp.pie(list_data, labels = label_list)
mp.show()
