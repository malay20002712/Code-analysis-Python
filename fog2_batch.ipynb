# %%
from pandas import *
from numpy import *
import matplotlib.pyplot as mp
import seaborn as sb

# %%
data = read_csv ('C:\\Users\\DELL\\Desktop\\NIT research\\pythonsim\\python sim\\fog2_batch\\Results\\Results_3_10_2.csv')
data.head()
# Out:
#    id    type   app    module    message  DES.src  DES.dst  TOPO.src  \
# 0   9  SINK_M  app1  Actuator  M.result1      133        1         7
# 1  11  SINK_M  app1  Actuator  M.result1      133        1         7
# 2  16  SINK_M  app1  Actuator  M.result1      142        1        11
# 3  10  SINK_M  app1  Actuator  M.result1      140        1         9
# 4  13  SINK_M  app1  Actuator  M.result1      142        1        11
#
#    TOPO.dst module.src  service     time_in    time_out   time_emit  \
# 0        35       Mod1        0  101.000004  101.000004  101.000004
# 1        35       Mod1        0  101.000004  101.000004  101.000004
# 2        35       Mod1        0  101.000004  101.000004  101.000002
# 3        35       Mod1        0  101.000004  101.000004  101.000004
# 4        35       Mod1        0  101.000005  101.000005  101.000004
#
#    time_reception
# 0      101.000004
# 1      101.000004
# 2      101.000004
# 3      101.000004
# 4      101.000005

# %%
df = DataFrame (data)

# %%
df
# Out:
#        id    type   app    module    message  DES.src  DES.dst  TOPO.src  \
# 0       9  SINK_M  app1  Actuator  M.result1      133        1         7
# 1      11  SINK_M  app1  Actuator  M.result1      133        1         7
# 2      16  SINK_M  app1  Actuator  M.result1      142        1        11
# 3      10  SINK_M  app1  Actuator  M.result1      140        1         9
# 4      13  SINK_M  app1  Actuator  M.result1      142        1        11
# ..    ...     ...   ...       ...        ...      ...      ...       ...
# 237  1081  SINK_M  app1  Actuator  M.result1     1219        1         9
# 238  1097  SINK_M  app1  Actuator  M.result1     1219        1         9
# 239   369  SINK_M  app1  Actuator  M.result1     1218        1        10
# 240   367  SINK_M  app1  Actuator  M.result1       -1        1         5
# 241   151  SINK_M  app1  Actuator  M.result1       -1        1        20
#
#      TOPO.dst module.src  service      time_in     time_out    time_emit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              242 non-null    int64
#  1   type            242 non-null    object
#  2   app             242 non-null    object
#  3   module          242 non-null    object
#  4   message         242 non-null    object
#  5   DES.src         242 non-null    int64
#  6   DES.dst         242 non-null    int64
#  7   TOPO.src        242 non-null    int64
#  8   TOPO.dst        242 non-null    int64
#  9   module.src      242 non-null    object
#  10  service         242 non-null    int64
#  11  time_in         242 non-null    float64
#  12  time_out        242 non-null    float64
#  13  time_emit       242 non-null    float64
#  14  time_reception  242 non-null    float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 28.5+ KB

# %%
df.describe()
# Out:
#                 id      DES.src  DES.dst    TOPO.src  TOPO.dst  service  \
# count   242.000000   242.000000    242.0  242.000000     242.0    242.0
# mean    360.508264   423.628099      1.0   13.144628      35.0      0.0
# std     334.209655   414.638274      0.0    7.540744       0.0      0.0
# min       3.000000    -1.000000      1.0    4.000000      35.0      0.0
# 25%      87.250000    -1.000000      1.0    8.000000      35.0      0.0
# 50%     228.000000   319.000000      1.0   11.000000      35.0      0.0
# 75%     609.500000   741.500000      1.0   16.000000      35.0      0.0
# max    1100.000000  1222.000000      1.0   33.000000      35.0      0.0
#
#            time_in     time_out    time_emit  time_reception
# count   242.000000   242.000000   242.000000      242.000000
# mean    988.557963   988.557963   669.595046      988.557963
# std     549.838584   549.838584   569.127316      549.838584
# min     101.000004   101.000004   101.000002      101.000004
# ...

# %%
DES = df ['DES.src'].tolist()

# %%
DES
# Out:
# [133,
#  133,
#  142,
#  140,
#  142,
#  142,
#  136,
#  140,
#  140,
#  -1,
#  -1,
#  -1,
#  -1,
#  202,
#  202,
#  199,
#  199,
#  199,
#  185,
#  202,
#  191,
#  191,
#  196,
#  191,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1,
#  257,
#  257,
#  258,
#  252,
#  262,
#  260,
#  258,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1,
#  313,
#  313,
#  313,
#  319,
#  316,
#  303,
#  319,
#  316,
#  319,
#  318,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1,
#  381,
#  370,
#  375,
#  375,
#  373,
#  380,
#  380,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1,
#  441,
#  441,
#  438,
#  440,
#  440,
#  437,
#  442,
#  437,
#  437,
#  444,
#  -1,
#  -1,
#  -1,
#  -1,
#  494,
#  500,
#  485,
#  501,
#  501,
#  493,
#  501,
#  514,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1,
#  557,
#  557,
#  561,
#  556,
#  559,
#  560,
#  561,
#  559,
#  560,
#  556,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1,
#  616,
#  605,
#  620,
#  620,
#  620,
#  642,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1,
#  680,
#  670,
#  676,
#  665,
#  681,
#  676,
#  676,
#  692,
#  -1,
# ...

# %%
TOPO = df ['TOPO.src'].tolist()

# %%
TOPO
# Out:
# [7,
#  7,
#  11,
#  9,
#  11,
#  11,
#  13,
#  9,
#  9,
#  8,
#  8,
#  15,
#  24,
#  4,
#  4,
#  7,
#  7,
#  7,
#  9,
#  4,
#  13,
#  13,
#  11,
#  13,
#  12,
#  8,
#  15,
#  33,
#  16,
#  7,
#  7,
#  11,
#  9,
#  4,
#  13,
#  11,
#  24,
#  23,
#  25,
#  15,
#  32,
#  7,
#  7,
#  7,
#  11,
#  9,
#  13,
#  11,
#  9,
#  11,
#  8,
#  20,
#  24,
#  6,
#  5,
#  23,
#  13,
#  4,
#  7,
#  7,
#  9,
#  11,
#  11,
#  25,
#  22,
#  29,
#  19,
#  24,
#  13,
#  13,
#  4,
#  7,
#  7,
#  11,
#  9,
#  11,
#  11,
#  19,
#  26,
#  15,
#  8,
#  28,
#  13,
#  4,
#  7,
#  9,
#  9,
#  11,
#  9,
#  17,
#  25,
#  6,
#  10,
#  12,
#  5,
#  4,
#  4,
#  7,
#  13,
#  11,
#  9,
#  7,
#  11,
#  9,
#  13,
#  22,
#  29,
#  12,
#  22,
#  30,
#  4,
#  9,
#  11,
#  11,
#  11,
#  16,
#  24,
#  21,
#  33,
#  8,
#  12,
#  4,
#  7,
#  9,
#  13,
#  11,
#  9,
#  9,
#  23,
#  32,
#  8,
#  22,
#  33,
#  4,
#  4,
#  13,
#  4,
#  11,
#  7,
#  9,
#  9,
#  9,
#  5,
#  16,
#  27,
#  21,
#  33,
#  21,
#  13,
#  11,
#  13,
#  9,
# ...

# %%
mp.plot (TOPO, DES, marker = 'o', color = 'red')
mp.xlabel ('TOPO')
mp.ylabel('DES')
mp.title('DES VS TOPO')
mp.grid (True)
mp.show()

# %%
time_in = df ['time_in'].tolist()

# %%
time_in
# Out:
# [101.00000419999998,
#  101.00000429999996,
#  101.00000439999997,
#  101.00000449999996,
#  101.00000459999995,
#  101.00000469999996,
#  101.00000619999996,
#  101.00000629999997,
#  101.00000639999996,
#  134.0000088415021,
#  152.00001170683163,
#  170.00001457216115,
#  188.00001743749067,
#  201.0000021,
#  201.0000041,
#  201.0000042,
#  201.0000043,
#  201.0000044,
#  201.0000045,
#  201.0000061,
#  201.0000062,
#  201.0000063,
#  201.0000064,
#  201.0000082,
#  206.0000203028202,
#  242.00008047474,
#  260.0000833400695,
#  278.00008620539904,
#  296.00008907072856,
#  301.00000220000004,
#  301.00000420000003,
#  301.00000430000006,
#  301.0000044000001,
#  301.0000061,
#  301.00000620000003,
#  301.00000630000005,
#  314.0000919360581,
#  332.0000948013876,
#  350.0000976667171,
#  368.0001005320466,
#  386.00010339737617,
#  401.0000022,
#  401.0000042,
#  401.00000430000006,
#  401.0000044000001,
#  401.0000045000001,
#  401.0000062,
#  401.00000630000005,
# ...

# %%
time_in_sort = time_in
time_in_sort.sort()

# %%
time_in_sort
# Out:
# [101.00000419999998,
#  101.00000429999996,
#  101.00000439999997,
#  101.00000449999996,
#  101.00000459999995,
#  101.00000469999996,
#  101.00000619999996,
#  101.00000629999997,
#  101.00000639999996,
#  134.0000088415021,
#  152.00001170683163,
#  170.00001457216115,
#  188.00001743749067,
#  201.0000021,
#  201.0000041,
#  201.0000042,
#  201.0000043,
#  201.0000044,
#  201.0000045,
#  201.0000061,
#  201.0000062,
#  201.0000063,
#  201.0000064,
#  201.0000082,
#  206.0000203028202,
#  242.00008047474,
#  260.0000833400695,
#  278.00008620539904,
#  296.00008907072856,
#  301.00000220000004,
#  301.00000420000003,
#  301.00000430000006,
#  301.0000044000001,
#  301.0000061,
#  301.00000620000003,
#  301.00000630000005,
#  314.0000919360581,
#  332.0000948013876,
#  350.0000976667171,
#  368.0001005320466,
#  386.00010339737617,
#  401.0000022,
#  401.0000042,
#  401.00000430000006,
#  401.0000044000001,
#  401.0000045000001,
#  401.0000062,
#  401.00000630000005,
# ...

# %%
mean_data_time_in = sum (time_in) / len (time_in)

# %%
print ('time in data: ', mean_data_time_in)
# Out:
# time in data:  988.5579630185281

# %%
data = []
dataValue = []
data.append ('TIME IN')
dataValue.append (mean_data_time_in)

# %%
time_out = df ['time_out'].tolist()

# %%
time_out_sort = time_out
time_out_sort.sort()

# %%
time_out_sort
# Out:
# [101.00000419999998,
#  101.00000429999996,
#  101.00000439999997,
#  101.00000449999996,
#  101.00000459999995,
#  101.00000469999996,
#  101.00000619999996,
#  101.00000629999997,
#  101.00000639999996,
#  134.0000088415021,
#  152.00001170683163,
#  170.00001457216115,
#  188.00001743749067,
#  201.0000021,
#  201.0000041,
#  201.0000042,
#  201.0000043,
#  201.0000044,
#  201.0000045,
#  201.0000061,
#  201.0000062,
#  201.0000063,
#  201.0000064,
#  201.0000082,
#  206.0000203028202,
#  242.00008047474,
#  260.0000833400695,
#  278.00008620539904,
#  296.00008907072856,
#  301.00000220000004,
#  301.00000420000003,
#  301.00000430000006,
#  301.0000044000001,
#  301.0000061,
#  301.00000620000003,
#  301.00000630000005,
#  314.0000919360581,
#  332.0000948013876,
#  350.0000976667171,
#  368.0001005320466,
#  386.00010339737617,
#  401.0000022,
#  401.0000042,
#  401.00000430000006,
#  401.0000044000001,
#  401.0000045000001,
#  401.0000062,
#  401.00000630000005,
# ...

# %%
mean_data_time_out = sum (time_out_sort) / len (time_out_sort)

# %%
print ("mean data time out :-", mean_data_time_out)
# Out:
# mean data time out :- 988.5579630185281

# %%
data.append ('TIME OUT')
dataValue.append (mean_data_time_out)

# %%
time_emit = df ['time_emit'].tolist()

# %%
time_emit
# Out:
# [101.000004,
#  101.000004,
#  101.000002,
#  101.000004,
#  101.000004,
#  101.000004,
#  101.00000599999998,
#  101.00000599999998,
#  101.00000599999998,
#  101.000004,
#  101.000004,
#  101.000004,
#  101.000002,
#  201.000002,
#  201.000004,
#  201.000002,
#  201.000004,
#  201.000004,
#  201.000004,
#  201.000006,
#  201.000006,
#  201.000006,
#  201.000004,
#  201.000008,
#  101.000004,
#  101.00000599999998,
#  101.000004,
#  101.00000599999998,
#  101.000004,
#  301.000002,
#  301.000004,
#  301.000002,
#  301.000004,
#  301.000006,
#  301.000006,
#  301.000006,
#  101.000002,
#  101.00000599999998,
#  101.00000599999998,
#  101.000004,
#  101.000004,
#  401.000002,
#  401.000004,
#  401.000004,
#  401.000004,
#  401.000004,
#  401.000004,
#  401.000006,
#  401.000006,
#  401.000006,
#  201.000002,
#  101.000004,
#  101.000004,
#  201.000002,
#  201.000006,
#  101.00000799999998,
#  501.000002,
#  501.000004,
#  501.000004,
#  501.000004,
#  501.000002,
#  501.000002,
# ...

# %%
mean_data_time_emit = sum (time_emit) / len (time_emit)

# %%
print ('time emit mean data :-', mean_data_time_emit)
# Out:
# time emit mean data :- 669.595046016529

# %%
data.append ('TIME EMIT')
dataValue.append (mean_data_time_emit)

# %%
time_reception = df ['time_reception'].tolist()
time_reception
# Out:
# [101.00000419999998,
#  101.00000429999996,
#  101.00000439999997,
#  101.00000449999996,
#  101.00000459999995,
#  101.00000469999996,
#  101.00000619999996,
#  101.00000629999997,
#  101.00000639999996,
#  134.0000088415021,
#  152.00001170683163,
#  170.00001457216115,
#  188.00001743749067,
#  201.0000021,
#  201.0000041,
#  201.0000042,
#  201.0000043,
#  201.0000044,
#  201.0000045,
#  201.0000061,
#  201.0000062,
#  201.0000063,
#  201.0000064,
#  201.0000082,
#  206.0000203028202,
#  242.00008047474,
#  260.0000833400695,
#  278.00008620539904,
#  296.00008907072856,
#  301.00000220000004,
#  301.00000420000003,
#  301.00000430000006,
#  301.0000044000001,
#  301.0000061,
#  301.00000620000003,
#  301.00000630000005,
#  314.0000919360581,
#  332.0000948013876,
#  350.0000976667171,
#  368.0001005320466,
#  386.00010339737617,
#  401.0000022,
#  401.0000042,
#  401.00000430000006,
#  401.0000044000001,
#  401.0000045000001,
#  401.0000062,
#  401.00000630000005,
# ...

# %%
mean_data_time_reception = sum (time_reception) / len (time_reception)
print ('mean time reception :-', mean_data_time_reception)
# Out:
# mean time reception :- 988.5579630185281

# %%
data.append ('TIME RECEPTION')
dataValue.append (mean_data_time_reception)

# %%
figure = mp.figure(figsize = (20, 7))
mp.pie (dataValue, labels = data)
mp.show ()

# %% [markdown]
# # AVERAGE TIME OUT

# %%
avg_time_out = sum (time_out) // len (time_out)
print ('Average time out: ', avg_time_out)
# Out:
# Average time out:  988.0

# %%
#average time in
avg_time_in = sum (time_in) // len (time_in)
print ('Average time in: ', avg_time_in)
# Out:
# Average time in:  988.0

# %%
#average time emit
avg_time_emit = sum (time_emit) // len (time_emit)
print ('Average time emit :-', avg_time_emit)
# Out:
# Average time emit :- 669.0

# %%
#average time reception
avg_time_reception = sum (time_reception) // len (time_reception)
print ('Average time reception :-', avg_time_reception)
# Out:
# Average time reception :- 988.0

# %%
mp.plot (time_out, time_in, linestyle = 'dashed', marker = 'o', color = 'red')
mp.xlabel ('TIME OUT')
mp.ylabel ('TIME IN')
mp.grid (True)
mp.show ()

# %%
time_emit
# Out:
# [101.000004,
#  101.000004,
#  101.000002,
#  101.000004,
#  101.000004,
#  101.000004,
#  101.00000599999998,
#  101.00000599999998,
#  101.00000599999998,
#  101.000004,
#  101.000004,
#  101.000004,
#  101.000002,
#  201.000002,
#  201.000004,
#  201.000002,
#  201.000004,
#  201.000004,
#  201.000004,
#  201.000006,
#  201.000006,
#  201.000006,
#  201.000004,
#  201.000008,
#  101.000004,
#  101.00000599999998,
#  101.000004,
#  101.00000599999998,
#  101.000004,
#  301.000002,
#  301.000004,
#  301.000002,
#  301.000004,
#  301.000006,
#  301.000006,
#  301.000006,
#  101.000002,
#  101.00000599999998,
#  101.00000599999998,
#  101.000004,
#  101.000004,
#  401.000002,
#  401.000004,
#  401.000004,
#  401.000004,
#  401.000004,
#  401.000004,
#  401.000006,
#  401.000006,
#  401.000006,
#  201.000002,
#  101.000004,
#  101.000004,
#  201.000002,
#  201.000006,
#  101.00000799999998,
#  501.000002,
#  501.000004,
#  501.000004,
#  501.000004,
#  501.000002,
#  501.000002,
# ...

# %%
time_out
# Out:
# [101.00000419999998,
#  101.00000429999996,
#  101.00000439999997,
#  101.00000449999996,
#  101.00000459999995,
#  101.00000469999996,
#  101.00000619999996,
#  101.00000629999997,
#  101.00000639999996,
#  134.0000088415021,
#  152.00001170683163,
#  170.00001457216115,
#  188.00001743749067,
#  201.0000021,
#  201.0000041,
#  201.0000042,
#  201.0000043,
#  201.0000044,
#  201.0000045,
#  201.0000061,
#  201.0000062,
#  201.0000063,
#  201.0000064,
#  201.0000082,
#  206.0000203028202,
#  242.00008047474,
#  260.0000833400695,
#  278.00008620539904,
#  296.00008907072856,
#  301.00000220000004,
#  301.00000420000003,
#  301.00000430000006,
#  301.0000044000001,
#  301.0000061,
#  301.00000620000003,
#  301.00000630000005,
#  314.0000919360581,
#  332.0000948013876,
#  350.0000976667171,
#  368.0001005320466,
#  386.00010339737617,
#  401.0000022,
#  401.0000042,
#  401.00000430000006,
#  401.0000044000001,
#  401.0000045000001,
#  401.0000062,
#  401.00000630000005,
# ...

# %%
mp.plot (time_reception, time_emit, linestyle = 'dashed', marker = 'o', color = 'red')
mp.xlabel ('time reception')
mp.ylabel ('time emit')
mp.grid(True)
mp.show ()
